# %%
# Age Distribution (Histogram)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("healthcare_dataset.csv")

plt.figure()
plt.hist(df["Age"],bins=20, color='red',edgecolor='Black' )
plt.title("Histogram of Age distribution ")
plt.xlabel("Age")
plt.ylabel("Number of Patients")
plt.show()

# %%
# Blood Group Distribution (Bar Graph)
plt.figure()
plt.bar(df["Blood_Group"],df["Patient_ID"], color = 'green', edgecolor='red')
plt.title("Bar Graph of Blood Group Distribution ")
plt.xlabel("Blood Group")
plt.ylabel("Patient ID")
plt.show()

# %%
# Bill Distribution (Scatter)
plt.figure()
plt.scatter(df["Patient_ID"],df["Bill_Amount"], color = 'yellow', marker="*")
plt.title("Scatter Graph Of Bill Distribution ")
plt.xlabel("Patient ID")
plt.ylabel("Bill")
plt.show()

# %%
# Age Distribution (Box Plot)
plt.figure()
sns.boxplot(df["Age"], color = 'gold')
plt.title("Box plot of Age Distribution ")
plt.ylabel("Age")
plt.show()
